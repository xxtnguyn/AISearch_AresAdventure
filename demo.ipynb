# %%
from DFS import DFS
from BFS import BFS
from UCS import UCS
from State_and_Game import Game
from MetricsTracker import MetricsTracker

# %% [markdown]
# #### Test 1

# %%
testcase = '''
1 99
############
##         #
#          #
# $ $      #
#. @      .#
############
'''

# print(testcase)
game = Game()
game.read_map_from_string(testcase)
tracker = MetricsTracker()

# print("======= DFS =======")
# route_and_weight = DFS(game, tracker)
# print(''.join(route_and_weight))
# tracker.print_metrics()
# tracker.reset()

route_and_weight = DFS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
tracker.reset()



# print("======= BFS =======")
# route_and_weight = BFS(game, tracker)
# print(route_and_weight)
# tracker.print_metrics()
# tracker.reset()

# print("======= UCS =======")
# route_and_weight = UCS(game, tracker)
# print(route_and_weight)
# tracker.print_metrics()
# Out:
# [('u', 0), ('u', 0), ('u', 0), ('r', 0), ('r', 0), ('d', 0), ('d', 0), ('L', np.int64(99)), ('d', 0), ('l', 0), ('U', np.int64(99)), ('d', 0), ('l', 0), ('U', np.int64(1)), ('d', 0), ('r', 0), ('r', 0), ('u', 0), ('u', 0), ('u', 0), ('l', 0), ('D', np.int64(99)), ('D', np.int64(99)), ('u', 0), ('u', 0), ('l', 0), ('D', np.int64(1)), ('u', 0), ('r', 0), ('r', 0), ('d', 0), ('d', 0), ('d', 0), ('L', np.int64(99)), ('u', 0), ('u', 0), ('l', 0), ('l', 0), ('d', 0), ('d', 0), ('R', np.int64(99)), ('l', 0), ('u', 0), ('R', np.int64(1)), ('d', 0), ('R', np.int64(99)), ('U', np.int64(1)), ('d', 0), ('l', 0), ('l', 0), ('u', 0), ('u', 0), ('r', 0), ('u', 0), ('r', 0), ('D', np.int64(1)), ('u', 0), ('r', 0), ('r', 0), ('d', 0), ('d', 0), ('d', 0), ('L', np.int64(99)), ('L', np.int64(99)), ('U', np.int64(1)), ('d', 0), ('L', np.int64(99)), ('u', 0), ('u', 0), ('u', 0), ('r', 0), ('D', np.int64(1)), ('D', np.int64(1)), ('l', 0), ('d', 0), ('R', np.int64(1)), ('R', np.int64(1)), ('R', np.int64(1)
# ...

# %% [markdown]
# #### Test level 25

# %%
testcase = '''
1 1 1
    ####
#####  ###
#   #   @###
# #    #$  #
#   ##$ $  #
#  ... #   #
#   ########
#####
'''
game = Game()
game.read_map_from_string(testcase)
tracker = MetricsTracker()

print("======= DFS =======")
route_and_weight = DFS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
tracker.reset()

print("======= BFS =======")
route_and_weight = BFS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
tracker.reset()

print("======= UCS =======")
route_and_weight = UCS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
# Out:
# ======= DFS =======
# ...

# %% [markdown]
# #### Test level 5

# %%
testcase = '''
1 1 1
 ####
 #  ###
 #$   #
##@$. #
# $#.##
#   .#
#    #
#    #
######
'''
game = Game()
game.read_map_from_string(testcase)
tracker = MetricsTracker()

print("======= DFS =======")
route_and_weight = DFS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
tracker.reset()

print("======= BFS =======")
route_and_weight = BFS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
tracker.reset()

print("======= UCS =======")
route_and_weight = UCS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
# Out:
# ======= DFS =======
# ...

# %% [markdown]
# #### Test level 10

# %%
testcase = '''
1 1 1
  ####
###  #
#@ .$#######
#   $     .#
# # $  #####
#      #  .#
#          #
#          #
############
'''
game = Game()
game.read_map_from_string(testcase)
tracker = MetricsTracker()

print("======= DFS =======")
route_and_weight = DFS(game, tracker)
print(route_and_weight)
tracker.print_metrics()
tracker.reset()

# print("======= BFS =======")
# route_and_weight = BFS(game, tracker)
# print(route_and_weight)
# tracker.print_metrics()
# tracker.reset()

# print("======= UCS =======")
# route_and_weight = UCS(game, tracker)
# print(route_and_weight)
# tracker.print_metrics()
# Out:
# ======= DFS =======
# ...
